# %%
print('很開心')
print('有跟上')
pirnt('python 課程')
print('good')
# Out:
# 很開心
# 有跟上
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 print('很開心')
#       2 print('有跟上')
# ----> 3 pirnt('python 課程')
#       4 print('good')
#
# NameError: name 'pirnt' is not defined

# %%
print('很開心')
print('有跟上')
print('python 課程')
print('good')
# Out:
# 很開心
# 有跟上
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 print('很開心')
#       2 print('有跟上')
# ----> 3 pirnt('python 課程')
#       4 print('good')
#
# NameError: name 'pirnt' is not defined

# %% [markdown]
# # b1
# ## b11
# ### b111
# #### b1111
# ##### b11111
